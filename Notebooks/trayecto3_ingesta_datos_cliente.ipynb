# %% [markdown]
# ## Fuentes de datos
#
# **Directorio:** `\\srvapwb12\SCG_INFORMACION_EXTERNA$\USUARIOS\GCIA BANCA DIGITAL` (Ana Belén Juncos)
#
# **Contenido de la carpeta:**
#
# - Usuarios de platadorma digital `ORA_Users.txt`
# - Crosseling de productos de Febrero a Abril `CLIPROD_CROSSELLING_YYYYMM.txt`
# - Transacciones monetarias y no monetares de Febrero a Abril: `Detalle_Trx_Monetarias_YYYYMM.txt` / `NoMonetarias_YYYYMM.txt`
#
# **Directorio:** `\\srvapwb12\SCG_INFORMACION_EXTERNA$\QV\USR\OUTPUT\Gestar` (Marcela Terreno)
#
# **Contenido de la carpeta:**
#
# - Transacciones mensuales de GESTAR - `Transacciones_Gestar_YYYYMM_NVO.txt`

# %% [markdown]
# ## Declaraciones de librerías

# %%
# Importo las librerias necesarias
import pandas as pd
import datetime as dt
import numpy as np
import os

# %%
# Funciones globales de uso general
def dateparse_(x):
    try:
        d = dt.datetime.strptime(x, '%d/%m/%Y')
    except:
        d = dt.datetime(1900, 1, 1)
    return d
dateparse = lambda x: dateparse_(x)

# %% [markdown]
# ## Depuración y generación del archivo de usuarios

# %% [markdown]
# ### Estructura del archivo
#
# |Campo    |Descripción   |
# |---    |---   |
# |ID_USER    |Id de usuario (Hash de 32 bytes)   |
# |EMAIL  |Correo electronico   |
# |FIRST_NAME |Nombre   |
# |LAST_NAME  |Apellido   |
# |MOBILE_NUMBER  |Teléfono celular   |
# |DOCUMENTO  |Documento (CUIT/CUIL)   |
# |FechaCreacion  |Fecha de OnBoarding   |
# |LAST_LOGIN |Último logín en la plataforma digital BANCON   |
# |SegFactor  |Segundo factor de autenticación   |

# %%
# Lectura de archivo
file = r'\\srvapwb12\SCG_INFORMACION_EXTERNA$\USUARIOS\GCIA BANCA DIGITAL\ORA_Users.txt'
df_us = pd.read_csv(file, 
    delimiter=';',
    encoding='latin-1',
    dtype={"DOCUMENTO": str, "LAST_LOGIN": str, "SegFactor": str},
    parse_dates=["FechaCreacion", "LAST_LOGIN"],
    date_parser=dateparse,
    usecols=["ID_USER", "DOCUMENTO", "FechaCreacion", "LAST_LOGIN", "SegFactor"])
df_us.shape
# Out:
# (917541, 5)

# %%
# Elimino los registros con fecha de último logín 1900-01-01
df_us = df_us[df_us["LAST_LOGIN"] != dt.datetime(1900, 1, 1)]

# %%
# Averiguar si hay o no CUIT/CUILs duplicados
ids = df_us["DOCUMENTO"]
df_us[ids.isin(ids[ids.duplicated()])].sort_values("DOCUMENTO")
# Out:
#                                  ID_USER    DOCUMENTO FechaCreacion  \
# 484554  ec0258dd773d4e518c261ca4a1291a0e  20043106261    2020-12-20
# 584347  a40b6b59c911450b892700b8a7549b0a  20043106261    2021-11-09
# 128921  ca859587dc2f4368a0a91e2e583d34be  20046189958    2019-09-09
# 114931  a8e526c2f12d40dcaf6b733df6f0fbf3  20046189958    2019-08-21
# 479361  79a200d4ad454a63a25c61cc492ab9b7  20049293209    2021-03-02
# ...                                  ...          ...           ...
# 898028  bbfdf324ce194746968c10eb15795361  27960094676    2020-02-13
# 235572  a5c980c815654b3fadb0e58ec0458840  27960159832    2020-02-28
# 814383  a841dbca361a4a4f9e7622c3171ecc46  27960159832    2021-04-06
# 537490  c9d18053509a4af1bcd52e6df537edc7  30710898967    2021-08-11
# 542739  b8fda53ffd93417bada4e9d8449b6751  30710898967    2021-08-17
#
#        LAST_LOGIN                SegFactor
# 484554 2021-09-10                      SMS
# 584347 2022-06-03                 Softoken
# 128921 2019-09-12                      SMS
# 114931 2022-05-31                      SMS
# 479361 2022-06-03                 Softoken
# ...           ...                      ...
# 898028 2021-03-28                      SMS
# 235572 2021-03-18                      SMS
# 814383 2022-06-02                 Softoken
# 537490 2021-08-12  No tiene segundo factor
# 542739 2021-08-17  No tiene segundo factor
#
# [12257 rows x 5 columns]

# %%
# Hay duplicados. Me quedo con el registro con la fecha de último login mas reciente
df_us = df_us.sort_values("LAST_LOGIN").groupby("DOCUMENTO").tail(1)
df_us.shape
# Out:
# (903291, 5)

# %%
# Grabo
file = os.path.abspath('..\Export') + r'\usuarios.csv'
df_us.to_csv(file, index=False)

# %%
# Borro lo que ya no es necesario para econnomizar memoria
df_us.drop(["FechaCreacion"], axis=1, inplace=True)

# %% [markdown]
# ## Depuración y generación del archivo de crosseling

# %% [markdown]
# ### Estructura del archivo

# %%
t_cs = {
    "CUITCLIE": str,
    "RELACION": str,
    "TIPOIMPN": str,
    "NATUJURI": str,
    "SUCURSAL": str,
    "BCRASECT": str,
    "BCRASEGO": str,
    "GRUPO_CLIENTE": str,
    "GRUPOGENERAL": str,
    "SUBGRUPO": str,
    "SEGMENTO_SUELDOS": str,
    "SEGMENTO_BANCAS": str
}

uc_cs = [
    "CUITCLIE",
    "RELACION",
    "TIPOIMPN",
    "NATUJURI",
    "SUCURSAL",
    "BCRASECT",
    "BCRASEGO",
    "GRUPO_CLIENTE",
    "GRUPOGENERAL",
    "SUBGRUPO",
    "SEGMENTO_SUELDOS",
    "SEGMENTO_BANCAS",
    "FUM",
    "ES_CAPITA",
    "CL_ACTIVO_FUM",
    "TIENE_I_CA_D",
    "TIENE_I_CA_P",
    "TIENE_I_CBESA",
    "TIENE_I_CC",
    "TIENE_I_CCAD",
    "TIENE_I_CS",
    "TIENE_I_FCI",
    "TIENE_I_PF",
    "TIENE_I_PR_HIP",
    "TIENE_I_PR_PERS",
    "TIENE_I_PREP",
    "TIENE_I_SE_PATR",
    "TIENE_I_SEG_VIDA",
    "TIENE_I_VISA",
    "TIENE_I_TJ_SOC",
    "SALDO_COMPUTO_SIST_2",
    "SALDO_COMPUTO_SIST_CC_MB",
    "SALDO_COMPUTO_SIST_CA_P",
    "SALDO_COMPUTO_SIST_CC_P",
    "SALDO_COMPUTO_SIST_FCI",
    "CROSS_IND"
]

# %%
# Lectura de archivo
# Solo tomamos Abril porque en la reunión de Data Driven se concluyó que solo el último es relevante
file = r'\\srvapwb12\SCG_INFORMACION_EXTERNA$\USUARIOS\GCIA BANCA DIGITAL\CLIPROD_CROSSELLING_202204.txt'
df_cs = pd.read_csv(file, 
    delimiter='|',
    nrows=5,
    encoding='latin-1',
    dtype=t_cs,
    parse_dates=["FUM"],
    usecols=uc_cs)
df_cs.shape
# Out:
# (5, 37)

# %%
# Anonimizo la identificación del usuario tomando el hash de la tabla de usuarios
df_cs = pd.merge(df_us, df_cs, how='inner', left_on='DOCUMENTO', right_on='CUITCLIE')
df_cs.drop(["DOCUMENTO", "CUITCLIE"], axis=1, inplace=True)

# %%
# Reemplazo los valores SI/NO y la convierto en una variable dicotómica
df_cs["CL_ACTIVO_FUM"].replace({"SI": 1, "NO": 0}, inplace=True)

# %%
# Grabo
file = os.path.abspath('..\Export') + r'\crosseling.csv'
df_cs.to_csv(file, index=False)

# %%
# Libero memoria
del df_cs
df_us.drop(["LAST_LOGIN", "SegFactor"], axis=1, inplace=True)

# %% [markdown]
# ## Depuración y generación del archivo de reclamos

# %% [markdown]
# ### Estructura del archivo
#
# |Campo    |Descripción   |
# |---    |---   |
# |Periodo    |Perído   |
# |ID |Id Gestar   |
# |CASETYPEID |Id de tipo caso   |
# |CASETYPE   |Descripción de tipo de caso   |
# |CANORIGID  |Id de canal originante   |
# |CANORIG    |Descripción de canal originante   |
# |TYPE_CODSUCURSAL   |Sucursal   |
# |STATEID    |Id de estado   |
# |State  |Descripción de estado   |
# |CREATEDDATE    |Fecha de creación del caso YYYYMMDD   |
# |CREATEDMONTH   |**Excluir** Mes de creación del caso   |
# |ENDDATE    |Fecha de cierre del caso   |
# |SING_TIPODOC   |Tipo de documento   |
# |SING_NRODOC    |Número de documento **(Ojo! A veces cargan acá el CUIT/CUIL y dejan el campo CUIT vacío)**  |
# |CUIT   |CUIT   |
# |CLIENTE    |**Excluir** Nombre del cliente   |
# |TYPE_NROCTA    |Tipo de cuenta   |
# |TYPE_NROTARJETA    |Número de cuenta   |
# |NIVEL 1    |Clasificación del caso Nivel 1   |
# |NIVEL 2    |Clasificación del caso Nivel 2   |
# |NIVEL 3    |Clasificación del caso Nivel 3   |
# |SOLVER |**Excluir** Nombre del Resolutor   |
# |TYPE_MARCATARJETA  |Tipo de marca de tarjeta   |
# |TPOSOLUCION_CALCULADO  |Tipo de solución   |
# |TYPE_IMPORTE_TOTAL_RECLAMADO   |Importe total reclamado   |
# |TYPE_IMPORTE_TOTAL_REINTEGRADO |Importe total reintegrado   |
# |Motivo_Baja_Producto   |Motivo de baja del producto   |
# |VIA    |**Via?**  |
# |CREADO POR |**Excluir** Nombre de quien cargó el caso   |
# |ID CREADOR |**Excluir** Id del creador del caso   |
# |ACEPTA CONTACTO    |Acepta contacto SI/NO   |
# |EMAIL  |**Excluir** Correo electrónico   |
# |TYPE MOTIVO GESTION BANCON |**Motivo de gestión BANCON**   |
# |DIAS_DEMORA_DETALLE    |Detalle días de demora   |
# |CASETYPEPATH   |**Ruta de tipo de caso?**   |
# |GRUPORESPONSABLE   |**Excluir** Grupo responsable   |
# |STARTDATE  |**Fecha y hora de carga del caso?**   |
# |CUSTOMERID |**Excluir** Id de cliente   |
# |SING_FECHANACIMIENTO   |**SING?** **Excluir** Fecha de nacimiento   |
# |SING_SEXO  |**SING?** **Excluir** Sexo   |
# |SING_PROVINCIA |**SING?** **Excluir** Provincia   |
# |SING_BARRIO    |**SING?** **Excluir** Barrio   |
# |CUSTWORKCITY   |**Excluir** Ciudad laboural del cliente   |
# |TYPE_SUCURSAL  |**Excluir** Sucursal   |
# |GRUPORESPONSABLEID |**Excluir** Id de grupo resolutor   |
# |TYPE_TC_TIPOTARJETA    |**TC** Tipo de tarjeta   |
# |TYPE_TARJETA_NRO   |Número de tarjeta   |
# |TYPE_RUBRO_COMERCIO    |Rubro del comercio   |
# |type_importe_total_reclamado_dolares   |Importe total reclamado en dólares   |
# |TYPE_CONVENIO  |Convenio   |
# |TYPE_UBICACION |Ubicación   |
# |type_tipo_plataforma_bancon    |Tipo de plataforma BANCON   |
# |type_motivo_gestion_bancon_empresas    |Motivo de gestión BANCON empresas   |
# |type_motivo_consulta_bancon_empresas   |Motivo consulta BANCON empresas   |
# |type_motivo_consulta_bancon    |Motivo consulta BANCON   |

# %%
uc_gt = [
    "ID",
    "CASETYPEID",
    "CASETYPE",
    "CANORIGID",
    "CANORIG",
    "TYPE_CODSUCURSAL",
    "STATEID",
    "State",
    "CREATEDDATE",
    "CREATEDMONTH",
    "ENDDATE",
    "SING_TIPODOC",
    "SING_NRODOC",
    "CUIT",
    "TYPE_NROCTA",
    "TYPE_NROTARJETA",
    "NIVEL 1",
    "NIVEL 2",
    "NIVEL 3",
    "TYPE_MARCATARJETA",
    "TPOSOLUCION_CALCULADO",
    "TYPE_IMPORTE_TOTAL_RECLAMADO",
    "TYPE_IMPORTE_TOTAL_REINTEGRADO",
    "Motivo_Baja_Producto",
    "VIA",
    "ACEPTA CONTACTO",
    "TYPE MOTIVO GESTION BANCON",
    "DIAS_DEMORA_DETALLE",
    "CASETYPEPATH",
    "STARTDATE",
    "TYPE_TC_TIPOTARJETA",
    "TYPE_TARJETA_NRO",
    "TYPE_RUBRO_COMERCIO",
    "type_importe_total_reclamado_dolares",
    "TYPE_CONVENIO",
    "TYPE_UBICACION",
    "type_tipo_plataforma_bancon",
    "type_motivo_gestion_bancon_empresas",
    "type_motivo_consulta_bancon_empresas",
    "type_motivo_consulta_bancon"
]

t_gt = {
    "ID": str,
    "CASETYPEID": str,
    "CANORIGID": str,
    "TYPE_CODSUCURSAL": str,
    "STATEID": str,
    "CREATEDMONTH": str,
    "SING_TIPODOC": str,
    "SING_NRODOC": str,
    "CUIT": str,
    "TYPE_NROCTA": str,
    "TYPE_NROTARJETA": str,
    "TYPE_MARCATARJETA": str,
    "TPOSOLUCION_CALCULADO": str,
    "TYPE_IMPORTE_TOTAL_RECLAMADO": str,
    "TYPE_IMPORTE_TOTAL_REINTEGRADO": str,
    "Motivo_Baja_Producto": str,
    "VIA": str,
    "TYPE_TARJETA_NRO": str,
    "TYPE_RUBRO_COMERCIO": str,
    "type_importe_total_reclamado_dolares": str,
    "TYPE_CONVENIO": str,
    "TYPE_UBICACION": str,
    "type_tipo_plataforma_bancon": str,
    "type_motivo_gestion_bancon_empresas": str,
    "type_motivo_consulta_bancon_empresas": str,
    "type_motivo_consulta_bancon": str
}

# %%
# Lectura de los archivos
file_mode = "w"
for i in ["202202", "202203", "202204"]:

    file = r'\\srvapwb12\SCG_INFORMACION_EXTERNA$\QV\USR\OUTPUT\Gestar\Transacciones_Gestar_{}_NVO.txt'.format(i)
    df_gt = pd.read_csv(file, 
        delimiter='|',
        encoding='latin-1',
        dtype=t_gt,
        parse_dates=["CREATEDDATE", "ENDDATE", "STARTDATE"],
        usecols=uc_gt)

    # Donde haya un CUIT con valor nulo lo plancho con el valor del DNI si su longitud de >= 11
    df_gt["CUIT"] = np.where(pd.isnull(df_gt["CUIT"]) & (df_gt["SING_NRODOC"].str.len()>=11), df_gt["SING_NRODOC"], df_gt["CUIT"])
    # Borrar todas las filas sin CUIT
    df_gt = df_gt[~pd.isnull(df_gt["CUIT"])]
    # Corrijo todos los CUIT que tienen tres ceros adelante
    df_gt.loc[(df_gt["CUIT"].str.len()>11) & (df_gt["CUIT"].str[0:3] == "000"), "CUIT"] = df_gt["CUIT"].str[3:14]
    # Corto los CUIT restantes a 11 posiciones (muchos tienen una coma detras)
    df_gt.loc[(df_gt["CUIT"].str.len()>11), "CUIT"] = df_gt["CUIT"].str[0:11]
    # Le saco el guión al mes
    df_gt["CREATEDMONTH"] = df_gt["CREATEDMONTH"].str[:4] + df_gt["CREATEDMONTH"].str[5:7]
    
    # Anonimizo la identificación del usuario tomando el hash de la tabla de usuarios
    df_gt = pd.merge(df_us, df_gt, how='inner', left_on='DOCUMENTO', right_on='CUIT')
    df_gt.drop(["DOCUMENTO", "CUIT"], axis=1, inplace=True)

    # Grabo
    file = os.path.abspath('..\Export') + r'\reclamos.csv'
    df_gt.to_csv(file, index=False, mode=file_mode, header=(file_mode == "w"))
    print(file, 'Filas:', len(df_gt.index), file_mode, (file_mode == "w")) 
    file_mode = "a"
# Out:
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\reclamos.csv Filas: 126900 w True
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\reclamos.csv Filas: 147237 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\reclamos.csv Filas: 132175 a False

# %%
# Libero memoria
del df_gt

# %% [markdown]
# ## Depuración y generación del archivo de movimientos

# %% [markdown]
# ### Estructura del archivo (Monetarias y no Monetarias)
#
# |Campo    |Descripción   |
# |---    |---   |
# |PERIODO    |Período YYYYMM   |
# |TIPO_CANAL |Tipo de canal   |
# |CANAL  |Canal (SUCURSAL/BANCON_MOBILE/BANCON_WEB)  |
# |TIPO_CLIENTE   |Tipo de cliente (EMPRESA/INDIVIDUO)  |
# |CUITCLIE   |CUIT/CUIL del cliente   |
# |GRUPO_OPERACION    |Grupo de operación   |
# |TIPO_OPERACION |Tipo de operación   |
# |TIPO_OPERACION2    |Tipo de operación 2   |
# |OPERACION  |Operación   |
# |SUCURSAL   |Sucursal   |
# |CAB    |CAB   |
# |IMPORTE    |Importe   |
# |ORIGEN |Origen   |
# |TIPO_TRX   |Tipo de transacción (MONETARIA/NOMONETARIA)   |
# |CANAL_RATIO    |**Canal Ratio?**   |
# |CLASIF_TRX |Clasificación de la transacción   |

# %%
# Borro las columnas de usuario si no fueron borradas antes
df_us.drop(["FechaCreacion", "LAST_LOGIN", "SegFactor"], axis=1, inplace=True)

# %%
# Proceso principal de lectura, transformación y grabación del archivo de transacciones
def process_file_tx(file_input: str, file_output: str):

    uc_tx = [
        "PERIODO",
        "TIPO_CANAL",
        "CANAL",
        "TIPO_CLIENTE",
        "CUITCLIE",
        "GRUPO_OPERACION",
        "TIPO_OPERACION",
        "TIPO_OPERACION2",
        "SUCURSAL",
        "IMPORTE",
        "ORIGEN"
    ]

    t_tx = {
        "PERIODO": str,
        "TIPO_CANAL": str,
        "CANAL": str,
        "TIPO_CLIENTE": str,
        "CUITCLIE": str,
        "GRUPO_OPERACION": str,
        "TIPO_OPERACION": str,
        "TIPO_OPERACION2": str,
        "SUCURSAL": str,
        "IMPORTE": float,
        "ORIGEN": str
    }

    # Lectura de archivo
    df_tx = pd.read_csv(file_input,
        iterator=True,
        #nrows=1_000_000,
        chunksize=1_000_000,
        delimiter='|',
        decimal=",",
        encoding='latin-1',
        dtype=t_tx,
        usecols=uc_tx)

    # Itero en el archivo, lo transformo y lo voy grabando por partes
    file_mode = 'w'
    for df_tx_chunk in df_tx:

        # Primero filtro los registros con CUIT = 0 y de banca individuos
        df_tx_chunk = df_tx_chunk[(df_tx_chunk["CUITCLIE"] != "0") & (df_tx_chunk["TIPO_CLIENTE"] == "INDIVIDUO")]

        # Anonimizo la identificación del usuario tomando el hash de la tabla de usuarios
        df_tx_chunk = pd.merge(df_us, df_tx_chunk, how='inner', left_on='DOCUMENTO', right_on='CUITCLIE')

        df_tx_chunk.drop(["DOCUMENTO", "CUITCLIE", "TIPO_CLIENTE"], axis=1, inplace=True)

        # Intercambio las columnas PERIODO y ID_USER
        cols_tx = list(df_tx_chunk.columns)
        col_a, col_b = cols_tx.index("ID_USER"), cols_tx.index("PERIODO")
        cols_tx[col_b], cols_tx[col_a] = cols_tx[col_a], cols_tx[col_b]
        df_tx_chunk = df_tx_chunk[cols_tx]

        # Voy grabando
        df_tx_chunk.to_csv(file_output, index=False, mode=file_mode, header=(file_mode == "w"))
        print(file_output, 'Filas:', len(df_tx_chunk.index), file_mode, (file_mode == "w")) 
        file_mode = "a"

# %%
# Procesar los 3 archivos de movimientos que tenemos disponibles de transacciones MONETARIAS
for per in ["202202", "202203", "202204"]:
    f_i = r"C:\Users\e21719832\Desktop\DataDriven\Data\Transacciones\Detalle_Trx_Monetarias_{}.txt".format(per)
    f_o = os.path.abspath("..\Export") + r"\Detalle_Trx_Monetarias_{}.csv".format(per)
    process_file_tx(f_i, f_o)
# Out:
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 865725 w True
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 995044 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 929577 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 851290 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 666912 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 212242 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 434515 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 725269 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 831552 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 866875 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 876479 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 881253 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 880012 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 880444 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 749444 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202202.csv Filas: 194601 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 854066 w True
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 984652 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 995968 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 816113 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 790340 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 694313 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 135532 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 407153 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 701665 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 820296 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 857269 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 868140 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 871630 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 868868 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 869737 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 863561 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 605790 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202203.csv Filas: 168757 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 872893 w True
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 983527 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 994204 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 818968 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 734105 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 214749 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 417341 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 696806 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 807307 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 852149 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 866134 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 876362 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 874255 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 877436 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 865319 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 576387 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_Monetarias_202204.csv Filas: 117573 a False

# %%
# Procesar los 3 archivos de movimientos que tenemos disponibles de transacciones NO MONETARIAS
for per in ["202202", "202203", "202204"]:
    f_i = r"C:\Users\e21719832\Desktop\DataDriven\Data\Transacciones\Detalle_Trx_NoMonetarias_{}.txt".format(per)
    f_o = os.path.abspath("..\Export") + r"\Detalle_Trx_NoMonetarias_{}.csv".format(per)
    process_file_tx(f_i, f_o)
# Out:
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 966642 w True
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 928498 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 999487 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 851731 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 967853 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 999857 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 963042 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 866390 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 981478 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 993704 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 970078 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 984977 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 970296 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 978375 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 999660 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 999791 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 999926 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 960481 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 783874 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 936055 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 977878 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 789302 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 557787 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 752775 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 503812 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202202.csv Filas: 17883 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 947805 w True
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 927061 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 989162 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 999689 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 999603 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 794022 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 986933 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 999704 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 999688 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 822130 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 950104 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 999231 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 990926 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 962285 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 981323 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 993124 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 951014 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 999475 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 999634 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 995228 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 735810 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 931171 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 945877 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 963371 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 756081 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 518262 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 748668 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 647848 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv Filas: 72664 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 951907 w True
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 935728 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 972480 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 999752 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 989744 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 803488 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 990281 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 999768 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 999666 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 809214 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 952726 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 998914 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 949755 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 999941 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 981192 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 978166 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 966188 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 999526 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 999610 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 1000000 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 904477 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 801750 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 934025 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 959058 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 930835 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 532188 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 666821 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 728566 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 531842 a False
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202204.csv Filas: 22386 a False

# %% [markdown]
# #### Los dataset de movimientos siguen siendo muy grandes para Colab asi que los agrupo

# %%
# Proceso principal de lectura, transformación y grabación del archivo de transacciones
def process_file_tx_sum(file_input: str, file_output: str):

    uc = [
        "ID_USER",
        "TIPO_CANAL",
        "CANAL",
        "TIPO_CLIENTE",
        "GRUPO_OPERACION",
        "TIPO_OPERACION",
        "TIPO_OPERACION2",
        "SUCURSAL",
        "ORIGEN",
        "IMPORTE",
    ]

    tc = {
        "ID_USER": str,
        "TIPO_CANAL": str,
        "CANAL": str,
        "TIPO_CLIENTE": str,
        "GRUPO_OPERACION": str,
        "TIPO_OPERACION": str,
        "TIPO_OPERACION2": str,
        "SUCURSAL": str,
        "ORIGEN": str,
        "IMPORTE": float,
    }

    # Lectura de archivo
    df = pd.read_csv(file_input,
        iterator=True,
        chunksize=1_000_000,
        encoding='latin-1',
        dtype=tc,
        usecols=uc)

    # Itero en el archivo, lo transformo y lo voy grabando por partes
    file_mode = 'w'
    for df_chunk in df:

        # Voy grabando
        df_chunk.to_csv(file_output, index=False, mode=file_mode, header=(file_mode == "w"))
        print(file_output, 'Filas:', len(df_chunk.index), file_mode, (file_mode == "w")) 
        file_mode = "a"

# %%
# Procesar los 3 archivos de movimientos que tenemos disponibles de transacciones MONETARIAS
dir = os.path.abspath("..\Export")
for per in ["202203"]: #, "202203", "202204"]:
    f_i = dir + r"\Detalle_Trx_NoMonetarias_{}.csv".format(per)
    f_o = dir + r"\Trx_Sum_NoMonetarias_{}.csv".format(per)
    print(f_i)
    print(f_o)
    #process_file_tx_sum(f_i, f_o)
# Out:
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Detalle_Trx_NoMonetarias_202203.csv
# c:\Users\e21719832\Desktop\DataDriven\Data\Export\Trx_Sum_NoMonetarias_202203.csv

# %%
uc = [
    "PERIODO",
    "ID_USER",
    "TIPO_CANAL",
    "CANAL",
    "GRUPO_OPERACION",
    "TIPO_OPERACION",
    "TIPO_OPERACION2",
    "SUCURSAL",
    "ORIGEN",
    "IMPORTE",
]

tc = {
    "PERIODO": str,
    "ID_USER": str,
    "TIPO_CANAL": str,
    "CANAL": str,
    "GRUPO_OPERACION": str,
    "TIPO_OPERACION": str,
    "TIPO_OPERACION2": str,
    "SUCURSAL": str,
    "ORIGEN": str,
    "IMPORTE": float,
}

# Lectura de archivo
df = pd.read_csv(f_i,
    iterator=True,
    chunksize=1_000_000,
    encoding='latin-1',
    dtype=tc,
    usecols=uc)

# %%
# Itero en el archivo agregando por partes
df_sum = pd.DataFrame()   
for df_chunk in df:
    df_sum = pd.concat([df_sum, df_chunk.groupby([
        "PERIODO",
        "ID_USER",
        "TIPO_CANAL",
        "CANAL",
        "GRUPO_OPERACION",
        "TIPO_OPERACION",
        "TIPO_OPERACION2",
        "SUCURSAL",
        "ORIGEN"]) \
        .aggregate(CANT_OPERACIONES=("IMPORTE", "count"), MONTO_TOTAL=("IMPORTE", "sum")) \
        .reset_index()])

# %%
df_sum.shape
# Out:
# (4404189, 11)

# %%
    df_sum = df_sum.groupby([
        "PERIODO",
        "ID_USER",
        "TIPO_CANAL",
        "CANAL",
        "GRUPO_OPERACION",
        "TIPO_OPERACION",
        "TIPO_OPERACION2",
        "SUCURSAL",
        "ORIGEN"]) \
        .aggregate("sum") \
        .reset_index()

# %%
df_sum.to_csv(f_o, index=False)

# %%
    # Voy grabando
    df_chunk.to_csv(f_o, index=False, mode=file_mode, header=(file_mode == "w"))
    print(f_o, 'Filas:', len(df_chunk.index), file_mode, (file_mode == "w")) 
    file_mode = "a"

# %%
df.groupby([
    "PERIODO",
    "ID_USER",
    "TIPO_CANAL",
    "CANAL",
    "GRUPO_OPERACION",
    "TIPO_OPERACION",
    "TIPO_OPERACION2",
    "SUCURSAL",
    "ORIGEN"]) \
    .aggregate(CANT_OPERACIONES=("IMPORTE", "count"), MONTO_TOTAL=("IMPORTE", "sum")) \
    .reset_index() \
    .to_csv(f_o, index=False)

# %%
df_sum.to_csv(f_o, index=False)

# %%
df_sum
# Out:
#                                  ID_USER            TIPO_CANAL  \
# 0       00005ab2860a40f68efd2f1ce323f6d2              INTERNET
# 1       000116e24b654229ba8e31135a1d74c2              INTERNET
# 2       00017218f8824cb2915e799cbc5c18d7              INTERNET
# 3       0001858cfb664f349f6dcac7a2bac27f              INTERNET
# 4       0001858cfb664f349f6dcac7a2bac27f              INTERNET
# ...                                  ...                   ...
# 402955  ffff90b30ad5437084ff9f3d1b0fe5ea              INTERNET
# 402956  ffff90b30ad5437084ff9f3d1b0fe5ea  PROCESOS CENTRALIZAD
# 402957  ffffaad9e4084135b8b6e328ab67d230              INTERNET
# 402958  ffffaad9e4084135b8b6e328ab67d230              INTERNET
# 402959  ffffcc9a165c4d108d34f69d867e870d            PRESENCIAL
#
#                    CANAL           GRUPO_OPERACION  TIPO_OPERACION  \
# 0           INTERBANKING                 TESORERIA  TRANSFERENCIAS
# 1          BANCON_MOBILE                 TESORERIA   RECAUDACIONES
# 2          BANCON_MOBILE                 TESORERIA   RECAUDACIONES
# 3             BANCON_WEB  ALTAS Y GEST COMERCIALES           ALTAS
# 4             BANCON_WEB                 TESORERIA   RECAUDACIONES
# ...                  ...                       ...             ...
# 402955        BANCON_WEB                 TESORERIA   RECAUDACIONES
# 402956  OP CENTRALIZADAS  ALTAS Y GEST COMERCIALES           ALTAS
# 402957     BANCON_MOBILE                 TESORERIA   RECAUDACIONES
# 402958     BANCON_MOBILE                 TESORERIA   RECAUDACIONES
# 402959         CASH PLUS                 TESORERIA    EXTRACCIONES
#
#          TIPO_OPERACION2 SUCURSAL  ORIGEN  CANT_OPERACIONES  MONTO_TOTAL
# 0       TRANSF RECIBIDAS      913  CAMOVS                 1      7650.00
# 1                  RESTO        0    OMNI                 3      2349.50
# 2                   AFIP        0    OMNI                 4    132208.55
# 3             PLAZO FIJO        0    OMNI                 1    160000.00
# 4                  RESTO        0    OMNI                 1      7367.50
# ...                  ...      ...     ...               ...          ...
# 402955             RESTO        0    OMNI                 1      1202.70
# 402956        PLAZO FIJO      422  PF_REP                 2   1007854.79
# 402957              AFIP        0    OMNI                 1       699.50
# 402958             RESTO        0    OMNI                 6     11419.94
# 402959                 -        0     PEI                 1      2750.00
#
# [402960 rows x 10 columns]

# %%
    # De paso miro todas las posibles combinaciones de campos de atributos
    #df_tx_typ = df_tx[["TIPO_CANAL", "CANAL", "GRUPO_OPERACION", "TIPO_OPERACION", "TIPO_OPERACION2"]].drop_duplicates()

# %%
#df_tx = pd.concat([chunk[chunk["CUITCLIE"] != "0"] for chunk in iter_tx])
